# %% [markdown]
# <a href="https://colab.research.google.com/github/AdrianCAmes/Go_Parallel_Backpropagation/blob/main/backpropagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Repositorios y archivos públicos**

# %% [markdown]
# Repositorio de GitHub:
# * https://github.com/AdrianCAmes/Go_Parallel_Backpropagation
#
# Google Colab Notebook:
# * https://colab.research.google.com/github/AdrianCAmes/Go_Parallel_Backpropagation/blob/main/backpropagation.ipynb

# %% [markdown]
# # **Generalidades**

# %% [markdown]
# El algoritmo implementado en este trabajo es Backpropagation, el cual es un algoritmo de aprendizaje supervisado. Se dice que es un algoritmo supervisado ya que, al momento de entrenar la red, se le dará un valor esperado por cada patrón de entrenamiento, lo cual le servirá para diagnosticar qué tan alejada está la respuesta obtenida de la respuesta correcta. Para ejecutar este algoritmo es imperativo realizar dos etapas, las cuales son:
# * **Propagación hacia adelante:** En esta etapa se propagan los datos de entrada para obtener una predicción de la red.
# * **Propagación hacia atrás:** En esta etapa se retropropaga el error desde la capa de salida hacia las capas anteriores y se usan los errores retropropagados para la actualización de los pesos y bias.

# %% [markdown]
# En este trabajo, se propone paralelizar el algoritmo dividiendo el set de datos inicial en cuatro partes. Luego de la división, se realizará paralelamente la propagación hacia adelante de cada una de las partes y, posteriormente, una vez que se han propagado todas, se avisa al hilo principal mediante el uso de canales y se prosigue con una sola etapa de propagación hacia atrás (aprendizaje). Una ejecución de lo mencionado anteriormente es considerado como una época, y el algoritmo realizará "n" cantidad de épocas para su aprendizaje. Luego, se plantea calcular el error de todo el modelo para estimar qué tan precisa es la predicción de resultados en la red neuronal. Esto se logará mediante el cálculo del error cuadrático medio de todas épocas. Finalmente, las métricas del modelo (error y tiempo de ejecución) serán impresas para su visualización.

# %% [markdown]
# Sobre el dataset usado, el que se tomó como referencia para el entrenamiento es el conocido dataset de Iris, el cual contiene información acerca de la clasificación de flores Iris dependiendo de ciertas características. Nótese que Iris es un tipo de flor y para el presente trabajo se están tomando en cuenta dos de sus clases: Iris Setosa e Iris Versicolour.
#
# Cada patrón de este dataset contiene cinco atributos, los cuales serán explicados a continuación.
# Los cuatro primeros valores de cada patrón de entraniemnto representan lo siguiente:
# * Longitud del sépalo en cm.
# * Ancho del sépalo en cm.
# * Longitud del pétalo en cm.
# * Ancho del pétalo en cm.
#
# El último atributo representa a qué clase pertenece la flor Iris evaluada, asímismo, este campo es el que se tomará como el valor esperado al cual nuestra red neuronal debería apuntar. Tómese como referencia la siguiente clasificación:
# * Clase:
#   - 0 -> Iris Setosa
#   - 1 -> Iris Versicolour
#
# Por favor, sírvase a encontrar la información más detallada sobre el trabajo en el README.md del repositorio de GitHub.

# %% [markdown]
# # **Instalando Go y Spin**

# %%
# !apt install golang-go spin 1> /dev/null && go version && spin -V
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# go version go1.10.4 linux/amd64
# Spin Version 6.4.6 -- 2 December 2016

# %% [markdown]
# # **Código del backpropagatio**n

# %%
# %%writefile backpropagation.go
# package main
#
# // importar paquetes necesarios
# import (
# 	"fmt"
# 	"time"
# 	"math"
# 	"math/rand"
# 	"encoding/csv"
# 	"net/http"
# 	"strconv"
# )
#
# // SOBRE LA RED NEURONAL
#
# // estructura de la red neuronal (perceptrón multicapa)
# type NeuralNetwork struct {
# 	hiddenWeights       [][]float64
# 	outputWeights       [][]float64
# 	hiddenBias          []float64
# 	outputBias          []float64
# 	epochErrors					[]float64
# 	modelError					float64
# 	learningRate 				float64
# 	epochs       				int
# 	lengthTrainingSet		int
# 	inputNeuronsAmount	int
# 	hiddenNeuronsAmount	int
# 	outputNeuronsAmount	int
# }
#
# // función para inicializar la red neuronal
# func (n *NeuralNetwork) initializeNetwork() {
# 	rand.Seed(time.Now().UnixNano())
#
# 	// inicialización de bias
# 	n.hiddenBias = make([]float64, n.hiddenNeuronsAmount)
# 	n.outputBias = make([]float64, n.outputNeuronsAmount)
# 	for i := 0; i < n.hiddenNeuronsAmount; i++ {
# 		n.hiddenBias[i] = rand.Float64()
# 	}
# 	for i := 0; i < n.outputNeuronsAmount; i++ {
# 		n.outputBias[i] = rand.Float64()
# 	}
#
# 	// inicialización de pesos
# 	n.hiddenWeights = make([][]float64, n.hiddenNeuronsAmount)
# 	n.outputWeights = make([][]float64, n.outputNeuronsAmount)
# 	for i := 0; i < n.hiddenNeuronsAmount; i++ {
# 		n.hiddenWeights[i] = make([]float64, n.inputNeuronsAmount)
# 		for j := 0; j < n.inputNeuronsAmount; j++ {
# 			n.hiddenWeights[i][j] = rand.Float64()
# 		}
# 	}
# 	for i := 0; i < n.outputNeuronsAmount; i++ {
# 		n.outputWeights[i] = make([]float64, n.hiddenNeuronsAmount)
# 		for j := 0; j < n.hiddenNeuronsAmount; j++ {
# 			n.outputWeights[i][j] = rand.Float64()
# 		}
# 	}
#
# 	// creación de vector para almacenar los errores de cada época
# 	n.epochErrors = make([]float64, n.epochs)
# }
#
# // FUNCIONES CON MATRICES
#
# // obtiene solo los inputs del dataset de entrenamiento
# func getInputSetOnly(trainingSet [][]float64) [][]float64 {
# 	inputs := make([][]float64, len(trainingSet))
# 	numberOfExpectedOutputs := 1
#
# 	for i := 0; i < len(trainingSet); i++ {
# 		inputs[i] = make([]float64, len(trainingSet[i])-numberOfExpectedOutputs)
# 		for j := 0; j < len(trainingSet[i])-numberOfExpectedOutputs; j++ {
# 			inputs[i][j] = trainingSet[i][j]
# 		}
# 	}
# 	return inputs
# }
#
# // obtiene solo los valores esperados del dataset de entrenamiento
# func getExpectedValuesOnly(trainingSet [][]float64) [][]float64 {
# 	expected := make([][]float64, len(trainingSet))
# 	numberOfExpectedOutputs := 1
#
# 	for i := 0; i < len(trainingSet); i++ {
# 		expected[i] = make([]float64, numberOfExpectedOutputs)
# 		for j := 0; j < 1; j++ {
# 			expected[i][j] = trainingSet[i][len(trainingSet[i])-numberOfExpectedOutputs]
# 		}
# 	}
# 	return expected
# }
#
# // obtiene la matriz transpuesta de una matriz
# func getMatTransposed(m1 [][]float64) [][]float64 {
# 	transposed := make([][]float64, len(m1[0]))
#
# 	for i := 0; i < len(m1[0]); i++ {
# 		transposed[i] = make([]float64, len(m1))
# 		for j := 0; j < len(m1); j++ {
# 			transposed[i][j] = m1[j][i]
# 		}
# 	}
# 	return transposed
# }
#
# // calcula la multipicación escalar entre dos matrices
# func matDotProduct(m1, m2 [][]float64) [][]float64 {
# 	product := make([][]float64, len(m1))
#
# 	for i := 0; i < len(m1); i++ {
# 		product[i] = make([]float64, len(m2))
# 		for j := 0; j < len(m2); j++ {
# 			product[i][j] = vecDotProduct(m1[i], m2[j])
# 		}
# 	}
# 	return product
# }
#
# // calcula la adición entre dos vectores
# func matAdd(m1, m2 [][]float64) [][]float64 {
# 	add := make([][]float64, len(m1))
#
# 	for i := 0; i < len(m1); i++ {
# 		add[i] = make([]float64, len(m1[i]))
# 		for j := 0; j < len(m1[i]); j++ {
# 			add[i][j] = m1[i][j] + m2[i][j]
# 		}
# 	}
# 	return add
# }
#
# // calcula la multiplicación de una matriz y un escalar
# func scalarMatMulitply(m1 [][]float64, s float64) [][]float64 {
# 	product := make([][]float64, len(m1))
#
# 	for i := 0; i < len(m1); i++ {
# 		product[i] = make([]float64, len(m1[i]))
# 		for j := 0; j < len(m1[i]); j++ {
# 			product[i][j] = m1[i][j] * s
# 		}
# 	}
# 	return product
# }
#
# // obtiene el error diferencial entre el valor esperado y el valor obtenido
# func getDifError(y, d [][]float64) [][]float64 {
# 	dif := make([][]float64, len(y))
#
# 	for i := 0; i < len(y); i++ {
# 		dif[i] = make([]float64, 1)
# 		dif[i][0] = d[i][0] - y[i][0]
# 	}
# 	return dif
# }
#
# // convierte la matriz de string a float64
# func matConvertToFloat64(m1 [][]string) [][]float64 {
# 	converted := make([][]float64, len(m1))
# 	for i := 0; i < len(m1); i++ {
# 		converted[i] = make([]float64, len(m1[i]))
# 		for j := 0; j < len(m1[i]); j++ {
# 			converted[i][j], _ = strconv.ParseFloat(m1[i][j], 64)
# 		}
# 	}
# 	return converted
# }
#
# // FUNCIONES CON VECTORES
#
# // calcula la multiplicación escalar entre dos vectores
# func vecDotProduct(v1, v2 []float64) float64 {
# 	product := 0.0
#
# 	for i := 0; i < len(v1); i++ {
# 		product += v1[i] * v2[i]
# 	}
# 	return product
# }
#
# // calcula la adición entre dos vectores
# func vecAdd(v1, v2 []float64) []float64 {
# 	add := make([]float64, len(v1))
#
# 	for i := 0; i < len(v1); i++ {
# 		add[i] = v1[i] + v2[i]
# 	}
# 	return add
# }
#
# // calcula la multiplicación de un vector y un escalar
# func scalarVecMutliply(v1 []float64, s float64) []float64 {
# 	product := make([]float64, len(v1))
#
# 	for i := 0; i < len(v1); i++ {
# 		product[i] = v1[i] * s
# 	}
# 	return product
# }
#
# // multiplica los valores de v1 con sus contrapartes en v2
# func vecMutliply(v1, v2 []float64) []float64 {
# 	product := make([]float64, len(v1))
#
# 	for i := 0; i < len(v1); i++ {
# 		product[i] = v1[i] * v2[i]
# 	}
# 	return product
# }
#
# // reduce una matriz a un vector
# func matReduce(m1 [][]float64) []float64 {
# 	reduced := make([]float64, len(m1[0]))
#
# 	for i := 0; i < len(m1[0]); i++ {
# 		reduced[i] = 0
# 		for j := 0; j < len(m1); j++ {
# 			reduced[i] += m1[j][i]
# 		}
# 	}
# 	return reduced
# }
#
# // función sigmoide
# func sigmoid(x float64) float64 {
# 	return 1.0 / (1.0 + math.Exp(-x))
# }
#
# // derivada de la función sigmoide
# func sigmoidDerivative(y float64) float64 {
# 	return y*(1*y)
# }
#
# // propaga hacia adelante los valores de entrada del dataset
# func (n *NeuralNetwork) frontPropagation(chFrontPropagation chan string, trainingSet [][]float64, numberOfSet int) ([][]float64, [][]float64) {
# 	// propagación de la capa de entrada a la capa oculta
# 	hiddenPropagation := make([][]float64, len(trainingSet))
# 	for i := 0; i < len(trainingSet); i++ {
# 		hiddenPropagation[i] = make([]float64, n.hiddenNeuronsAmount)
# 		for j := 0; j < n.hiddenNeuronsAmount; j++ {
# 			hiddenPropagation[i][j] = sigmoid(vecDotProduct(trainingSet[i][:n.inputNeuronsAmount], n.hiddenWeights[j]) + n.hiddenBias[j])
# 		}
# 	}
#
# 	// propagación de la capa oculta a la capa de salida
# 	outputPropagation := make([][]float64, len(trainingSet))
# 	for i := 0; i < len(trainingSet); i++ {
# 		outputPropagation[i] = make([]float64, n.outputNeuronsAmount)
# 		for j := 0; j < n.outputNeuronsAmount; j++ {
# 			outputPropagation[i][j] = sigmoid(vecDotProduct(hiddenPropagation[i], n.hiddenWeights[j]) + n.outputBias[j])
# 		}
# 	}
#
# 	// se avisa al canal que ya terminó la propagación en esta función
# 	chFrontPropagation <- fmt.Sprintf("Propagated set %d", numberOfSet)
#
# 	// devolución los valores finales de la capa intermedia y oculta, ya que se usaran en la propagación hacia atrás
# 	return hiddenPropagation, outputPropagation
# }
#
# // función de la propagación hacia atrás
# func (n *NeuralNetwork) backPropagation(hiddenPropagation, outputPropagation, trainingSet [][]float64, epoch int) {
# 	// cálculo del error de la capa de salida
# 	outputPredictedError := getDifError(outputPropagation, getExpectedValuesOnly(trainingSet))
#
# 	// cálculo de la derivada sigmoidal de los valores finales de la capa de salida
# 	derivativeOutputPropagation := make([][]float64, len(outputPropagation))
# 	for i := 0; i < len(outputPropagation); i++ {
# 		derivativeOutputPropagation[i] = make([]float64, len(outputPropagation[i]))
# 		for j := 0; j < len(outputPropagation[i]); j++ {
# 			derivativeOutputPropagation[i][j] = sigmoidDerivative(outputPropagation[i][j])
# 		}
# 	}
#
# 	// cálculo del delta de la capa de salida
# 	outputPredictedDelta := make([][]float64, len(outputPredictedError))
# 	for i := 0; i < len(outputPredictedError); i++ {
# 		outputPredictedDelta[i] = vecMutliply(derivativeOutputPropagation[i], outputPredictedError[i])
# 	}
#
# 	// cálculo del error de la capa intermedia
# 	hiddenPredictedError := matDotProduct(outputPredictedDelta, getMatTransposed(n.outputWeights));
#
# 	// cálculo de la derivada sigmoidal de los valores finales de la capa intermedia
# 	derivativeHiddenPropagation := make([][]float64, len(hiddenPropagation))
# 	for i := 0; i < len(hiddenPropagation); i++ {
# 		derivativeHiddenPropagation[i] = make([]float64, len(hiddenPropagation[i]))
# 		for j := 0; j < len(hiddenPropagation[i]); j++ {
# 			derivativeHiddenPropagation[i][j] = sigmoidDerivative(hiddenPropagation[i][j])
# 		}
# 	}
#
# 	// cálculo del delta de la capa intermedia
# 	hiddenPredictedDelta := make([][]float64, len(hiddenPredictedError))
# 	for i := 0; i < len(outputPredictedError); i++ {
# 		hiddenPredictedDelta[i] = vecMutliply(derivativeHiddenPropagation[i], hiddenPredictedError[i])
# 	}
#
# 	// actualización de los pesos y bias
# 	n.outputWeights = matAdd(n.outputWeights, scalarMatMulitply(getMatTransposed(matDotProduct(getMatTransposed(hiddenPropagation), getMatTransposed(outputPredictedDelta))), n.learningRate))
# 	n.outputBias = vecAdd(n.outputBias, scalarVecMutliply(matReduce(outputPredictedDelta), n.learningRate))
# 	n.hiddenWeights = matAdd(n.hiddenWeights, scalarMatMulitply(getMatTransposed(matDotProduct(getMatTransposed(getInputSetOnly(trainingSet)), getMatTransposed(hiddenPredictedDelta))), n.learningRate))
# 	n.hiddenBias = vecAdd(n.hiddenBias, scalarVecMutliply(matReduce(hiddenPredictedDelta), n.learningRate))
#
# 	// cálculo y almacén del error de la época
# 	reducedPredictedError := matReduce(outputPredictedError)[0]/float64(len(trainingSet))
# 	n.epochErrors[epoch] = reducedPredictedError*reducedPredictedError
# }
#
# // FUNCIONES CON ARCHIVOS CSV
#
# // obtiene y lee el archivo csv de la url especificada
# func readCSVFromUrl(url string) ([][]string, error) {
# 	resp, err := http.Get(url)
# 	if err != nil {
# 		return nil, err
# 	}
# 	fmt.Println(resp.Body)
# 	defer resp.Body.Close()
# 	reader := csv.NewReader(resp.Body)
# 	reader.Comma = ','
# 	data, err := reader.ReadAll()
# 	if err != nil {
# 		return nil, err
# 	}
#
# 	return data, nil
# }
#
# func main() {
# 	// inicialización eel tiempo (para medir cuánto se demora en ejecutarse)
# 	start := time.Now()
#
# 	// obtenemos el datset de entrenamiento desde el repositorio online
# 	url := "https://raw.githubusercontent.com/AdrianCAmes/Go_Parallel_Backpropagation/main/iris_dataset.csv"
# 	data, _ := readCSVFromUrl(url)
# 	trainingSet := matConvertToFloat64(data)
#
# 	// inicialización de la red neuronal
# 	network := NeuralNetwork{
# 		lengthTrainingSet: len(trainingSet),
# 		inputNeuronsAmount: 4,
# 		hiddenNeuronsAmount: 2,
# 		outputNeuronsAmount: 1,
# 		epochs: 1000,
# 		learningRate: 0.3,
# 	}
# 	network.initializeNetwork()
#
# 	// división del dataset en 4 secciones de entrenamiento
# 	lengthTrainingSet := network.lengthTrainingSet
# 	firstTrainingSection := trainingSet[:lengthTrainingSet/4]
# 	secondTrainingSection := trainingSet[lengthTrainingSet/4:2*lengthTrainingSet/4]
# 	thirdTrainingSection := trainingSet[2*lengthTrainingSet/4:3*lengthTrainingSet/4]
# 	fourthTrainingSection := trainingSet[3*lengthTrainingSet/4:]
#
# 	// inicialización y cierre anticipado del canal por el cual se compartirá información de la propagaciónh hacia adelante
# 	chFrontPropagation := make(chan string)
# 	defer close(chFrontPropagation)
#
# 	// ciclo for por cada época
# 	for i := 0; i < network.epochs; i++ {
# 		fmt.Printf("Epoch %d \n", i)
#
# 		// ejecución paralela de la propagación hacia adelante de cada sección de entrenamiento
# 		finishedSets := 0
# 		var output1, hidden1, output2, hidden2, output3, hidden3, output4, hidden4 [][]float64
# 		go func() { hidden1, output1 = network.frontPropagation(chFrontPropagation, firstTrainingSection, 1) }()
# 		go func() { hidden2, output2 = network.frontPropagation(chFrontPropagation, secondTrainingSection, 2) }()
# 		go func() { hidden3, output3 = network.frontPropagation(chFrontPropagation, thirdTrainingSection, 3) }()
# 		go func() { hidden4, output4 = network.frontPropagation(chFrontPropagation, fourthTrainingSection, 4) }()
# 		for  {
# 			msg := <-chFrontPropagation
# 			fmt.Printf("Msg: %s \n", msg)
# 			if (msg[:10] == "Propagated") {
# 				finishedSets += 1
# 			}
# 			// si todas las secciones se han propagado hacia adelante, se rompe el ciclo
# 			if (finishedSets == 4) {
# 				time.Sleep(360000 * time.Nanosecond)
# 				break;
# 			}
# 		}
# 		// combinación de los resultados de cada sección de aprendizaje
# 		propagatedGeneralOutput := make([][]float64, lengthTrainingSet)
# 		propagatedGeneralHidden := make([][]float64, lengthTrainingSet)
# 		// -- combinación de la primera sección
# 		indexHelper := 0
# 		for j := 0; j < len(output1); j++ {
# 			propagatedGeneralOutput[j+indexHelper] = output1[j]
# 			propagatedGeneralHidden[j+indexHelper] = hidden1[j]
# 		}
# 		// -- combinación de la segunda sección
# 		indexHelper = indexHelper + len(output1)
# 		for j := 0; j < len(output2); j++ {
# 			propagatedGeneralOutput[j+indexHelper] = output2[j]
# 			propagatedGeneralHidden[j+indexHelper] = hidden2[j]
# 		}
# 		// -- combinación de la tercera sección
# 		indexHelper = indexHelper + len(output2)
# 		for j := 0; j < len(output3); j++ {
# 			propagatedGeneralOutput[j+indexHelper] = output3[j]
# 			propagatedGeneralHidden[j+indexHelper] = hidden3[j]
# 		}
# 		// -- combinación de la cuarta sección
# 		indexHelper = indexHelper + len(output3)
# 		for j := 0; j < len(output4); j++ {
# 			propagatedGeneralOutput[j+indexHelper] = output4[j]
# 			propagatedGeneralHidden[j+indexHelper] = hidden4[j]
# 		}
#
# 		// propagación hacia atrás y aprendizaje de la red neuronal
# 		network.backPropagation(propagatedGeneralHidden, propagatedGeneralOutput, trainingSet, i)
# 		fmt.Printf("Learned in epoch %d\n\n", i)
# 	}
#
# 	// cálculo del error general del modelo
# 	for i := 0; i < len(network.epochErrors); i++ {
# 		network.modelError += network.epochErrors[i]/float64(network.epochs)
# 	}
#
# 	// cálculo del tiempo transcurrido
# 	elapsed := time.Since(start)
#
# 	// visualización de métricas
# 	fmt.Printf("\n---------------------------\n")
# 	fmt.Printf("METRICS")
# 	fmt.Printf("\n---------------------------\n")
# 	fmt.Printf("Model error: %f\n", network.modelError)
# 	fmt.Printf("Execution took %s", elapsed)
# }
# Out:
# Overwriting backpropagation.go

# %% [markdown]
# # **Ejecución y prueba del algoritmo**

# %%
# !go run backpropagation.go
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Msg: Propagated set 3
# Learned in epoch 286
#
# Epoch 287
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 287
#
# Epoch 288
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 288
#
# Epoch 289
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 289
#
# Epoch 290
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 290
#
# Epoch 291
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 291
#
# Epoch 292
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 292
#
# Epoch 293
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 293
#
# Epoch 294
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 294
#
# Epoch 295
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 295
#
# Epoch 296
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 296
#
# Epoch 297
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 297
#
# Epoch 298
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 298
#
# Epoch 299
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 299
#
# Epoch 300
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 300
#
# Epoch 301
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 301
#
# Epoch 302
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 302
#
# Epoch 303
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 303
#
# Epoch 304
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 304
#
# Epoch 305
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 305
#
# Epoch 306
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 306
#
# Epoch 307
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 307
#
# Epoch 308
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 308
#
# Epoch 309
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 309
#
# Epoch 310
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 310
#
# Epoch 311
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 311
#
# Epoch 312
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 312
#
# Epoch 313
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 313
#
# Epoch 314
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 314
#
# Epoch 315
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 315
#
# Epoch 316
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 316
#
# Epoch 317
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 317
#
# Epoch 318
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 318
#
# Epoch 319
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 319
#
# Epoch 320
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 320
#
# Epoch 321
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 321
#
# Epoch 322
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 322
#
# Epoch 323
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 323
#
# Epoch 324
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 324
#
# Epoch 325
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 325
#
# Epoch 326
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 326
#
# Epoch 327
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 327
#
# Epoch 328
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 328
#
# Epoch 329
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 329
#
# Epoch 330
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 330
#
# Epoch 331
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 331
#
# Epoch 332
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 332
#
# Epoch 333
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 333
#
# Epoch 334
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 334
#
# Epoch 335
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 335
#
# Epoch 336
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 336
#
# Epoch 337
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 337
#
# Epoch 338
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 338
#
# Epoch 339
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 339
#
# Epoch 340
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 340
#
# Epoch 341
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 341
#
# Epoch 342
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 342
#
# Epoch 343
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 343
#
# Epoch 344
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 344
#
# Epoch 345
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 345
#
# Epoch 346
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 346
#
# Epoch 347
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 347
#
# Epoch 348
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 348
#
# Epoch 349
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 349
#
# Epoch 350
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 350
#
# Epoch 351
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 351
#
# Epoch 352
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 352
#
# Epoch 353
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 353
#
# Epoch 354
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 354
#
# Epoch 355
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 355
#
# Epoch 356
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 356
#
# Epoch 357
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 357
#
# Epoch 358
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 358
#
# Epoch 359
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 359
#
# Epoch 360
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 360
#
# Epoch 361
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 361
#
# Epoch 362
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 362
#
# Epoch 363
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 363
#
# Epoch 364
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 364
#
# Epoch 365
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 365
#
# Epoch 366
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 366
#
# Epoch 367
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 367
#
# Epoch 368
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 368
#
# Epoch 369
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 369
#
# Epoch 370
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 370
#
# Epoch 371
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 371
#
# Epoch 372
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 372
#
# Epoch 373
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 373
#
# Epoch 374
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 374
#
# Epoch 375
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 375
#
# Epoch 376
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 376
#
# Epoch 377
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 377
#
# Epoch 378
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 378
#
# Epoch 379
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 379
#
# Epoch 380
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 380
#
# Epoch 381
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 381
#
# Epoch 382
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 382
#
# Epoch 383
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 383
#
# Epoch 384
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 384
#
# Epoch 385
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 385
#
# Epoch 386
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 386
#
# Epoch 387
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 387
#
# Epoch 388
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 388
#
# Epoch 389
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 389
#
# Epoch 390
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 390
#
# Epoch 391
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 391
#
# Epoch 392
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 392
#
# Epoch 393
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 393
#
# Epoch 394
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 394
#
# Epoch 395
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 395
#
# Epoch 396
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 396
#
# Epoch 397
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 397
#
# Epoch 398
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 398
#
# Epoch 399
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 399
#
# Epoch 400
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 400
#
# Epoch 401
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 401
#
# Epoch 402
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 402
#
# Epoch 403
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 403
#
# Epoch 404
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 404
#
# Epoch 405
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 405
#
# Epoch 406
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 406
#
# Epoch 407
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 407
#
# Epoch 408
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 408
#
# Epoch 409
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 409
#
# Epoch 410
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 410
#
# Epoch 411
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 411
#
# Epoch 412
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 412
#
# Epoch 413
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 413
#
# Epoch 414
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 414
#
# Epoch 415
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 415
#
# Epoch 416
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 416
#
# Epoch 417
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 417
#
# Epoch 418
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 418
#
# Epoch 419
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 419
#
# Epoch 420
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 420
#
# Epoch 421
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 421
#
# Epoch 422
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 422
#
# Epoch 423
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 423
#
# Epoch 424
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 424
#
# Epoch 425
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 425
#
# Epoch 426
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 426
#
# Epoch 427
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 427
#
# Epoch 428
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 428
#
# Epoch 429
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 429
#
# Epoch 430
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 430
#
# Epoch 431
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 431
#
# Epoch 432
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 432
#
# Epoch 433
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 433
#
# Epoch 434
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 434
#
# Epoch 435
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 435
#
# Epoch 436
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 436
#
# Epoch 437
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 437
#
# Epoch 438
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 438
#
# Epoch 439
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 439
#
# Epoch 440
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 440
#
# Epoch 441
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 441
#
# Epoch 442
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 442
#
# Epoch 443
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 443
#
# Epoch 444
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 444
#
# Epoch 445
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 445
#
# Epoch 446
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 446
#
# Epoch 447
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 447
#
# Epoch 448
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 448
#
# Epoch 449
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 449
#
# Epoch 450
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 450
#
# Epoch 451
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 451
#
# Epoch 452
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 452
#
# Epoch 453
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 453
#
# Epoch 454
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 454
#
# Epoch 455
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 455
#
# Epoch 456
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 456
#
# Epoch 457
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 457
#
# Epoch 458
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 458
#
# Epoch 459
# Msg: Propagated set 2
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 459
#
# Epoch 460
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 460
#
# Epoch 461
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 461
#
# Epoch 462
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 462
#
# Epoch 463
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 463
#
# Epoch 464
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 464
#
# Epoch 465
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 465
#
# Epoch 466
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 466
#
# Epoch 467
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 467
#
# Epoch 468
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 468
#
# Epoch 469
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 469
#
# Epoch 470
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 470
#
# Epoch 471
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 471
#
# Epoch 472
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 472
#
# Epoch 473
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 473
#
# Epoch 474
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 474
#
# Epoch 475
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 475
#
# Epoch 476
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 476
#
# Epoch 477
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 477
#
# Epoch 478
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 478
#
# Epoch 479
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 479
#
# Epoch 480
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 480
#
# Epoch 481
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 481
#
# Epoch 482
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 482
#
# Epoch 483
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 483
#
# Epoch 484
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 484
#
# Epoch 485
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 485
#
# Epoch 486
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 486
#
# Epoch 487
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 487
#
# Epoch 488
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 488
#
# Epoch 489
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 489
#
# Epoch 490
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 490
#
# Epoch 491
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 491
#
# Epoch 492
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 492
#
# Epoch 493
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 493
#
# Epoch 494
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 494
#
# Epoch 495
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 495
#
# Epoch 496
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 496
#
# Epoch 497
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 497
#
# Epoch 498
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 498
#
# Epoch 499
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 499
#
# Epoch 500
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 500
#
# Epoch 501
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 501
#
# Epoch 502
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 502
#
# Epoch 503
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 503
#
# Epoch 504
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 504
#
# Epoch 505
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 505
#
# Epoch 506
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 506
#
# Epoch 507
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 507
#
# Epoch 508
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 508
#
# Epoch 509
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 509
#
# Epoch 510
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 510
#
# Epoch 511
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 511
#
# Epoch 512
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 512
#
# Epoch 513
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 513
#
# Epoch 514
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 514
#
# Epoch 515
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 515
#
# Epoch 516
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 516
#
# Epoch 517
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 517
#
# Epoch 518
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 518
#
# Epoch 519
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 519
#
# Epoch 520
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 520
#
# Epoch 521
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 521
#
# Epoch 522
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 522
#
# Epoch 523
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 523
#
# Epoch 524
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 524
#
# Epoch 525
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 4
# Learned in epoch 525
#
# Epoch 526
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 526
#
# Epoch 527
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 527
#
# Epoch 528
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 528
#
# Epoch 529
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 529
#
# Epoch 530
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 530
#
# Epoch 531
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 531
#
# Epoch 532
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 532
#
# Epoch 533
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 533
#
# Epoch 534
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 534
#
# Epoch 535
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 535
#
# Epoch 536
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 536
#
# Epoch 537
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 537
#
# Epoch 538
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 538
#
# Epoch 539
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 539
#
# Epoch 540
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 540
#
# Epoch 541
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 541
#
# Epoch 542
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 542
#
# Epoch 543
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 543
#
# Epoch 544
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 544
#
# Epoch 545
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 545
#
# Epoch 546
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 546
#
# Epoch 547
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 547
#
# Epoch 548
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 548
#
# Epoch 549
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 549
#
# Epoch 550
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 550
#
# Epoch 551
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 551
#
# Epoch 552
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 552
#
# Epoch 553
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 553
#
# Epoch 554
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 554
#
# Epoch 555
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 555
#
# Epoch 556
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 4
# Learned in epoch 556
#
# Epoch 557
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 557
#
# Epoch 558
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 558
#
# Epoch 559
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 559
#
# Epoch 560
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 560
#
# Epoch 561
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 561
#
# Epoch 562
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 562
#
# Epoch 563
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 563
#
# Epoch 564
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 564
#
# Epoch 565
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 565
#
# Epoch 566
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 566
#
# Epoch 567
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 567
#
# Epoch 568
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 568
#
# Epoch 569
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 569
#
# Epoch 570
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 570
#
# Epoch 571
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 571
#
# Epoch 572
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 572
#
# Epoch 573
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 573
#
# Epoch 574
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 574
#
# Epoch 575
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 575
#
# Epoch 576
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 576
#
# Epoch 577
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 577
#
# Epoch 578
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 578
#
# Epoch 579
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 579
#
# Epoch 580
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 580
#
# Epoch 581
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 581
#
# Epoch 582
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 582
#
# Epoch 583
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 583
#
# Epoch 584
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 584
#
# Epoch 585
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 585
#
# Epoch 586
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 586
#
# Epoch 587
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 587
#
# Epoch 588
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 588
#
# Epoch 589
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 589
#
# Epoch 590
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 590
#
# Epoch 591
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 591
#
# Epoch 592
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 592
#
# Epoch 593
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 593
#
# Epoch 594
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 594
#
# Epoch 595
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 595
#
# Epoch 596
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 596
#
# Epoch 597
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 597
#
# Epoch 598
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 598
#
# Epoch 599
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 599
#
# Epoch 600
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 600
#
# Epoch 601
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 601
#
# Epoch 602
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 602
#
# Epoch 603
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 603
#
# Epoch 604
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 604
#
# Epoch 605
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 605
#
# Epoch 606
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 606
#
# Epoch 607
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 607
#
# Epoch 608
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 608
#
# Epoch 609
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 609
#
# Epoch 610
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 610
#
# Epoch 611
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 611
#
# Epoch 612
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 612
#
# Epoch 613
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 613
#
# Epoch 614
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 614
#
# Epoch 615
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 615
#
# Epoch 616
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 616
#
# Epoch 617
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 617
#
# Epoch 618
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 618
#
# Epoch 619
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 619
#
# Epoch 620
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 620
#
# Epoch 621
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 621
#
# Epoch 622
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 622
#
# Epoch 623
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 623
#
# Epoch 624
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 624
#
# Epoch 625
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 625
#
# Epoch 626
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 626
#
# Epoch 627
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 627
#
# Epoch 628
# Msg: Propagated set 2
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 628
#
# Epoch 629
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 629
#
# Epoch 630
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 630
#
# Epoch 631
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 4
# Learned in epoch 631
#
# Epoch 632
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 632
#
# Epoch 633
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 633
#
# Epoch 634
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 634
#
# Epoch 635
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 635
#
# Epoch 636
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 636
#
# Epoch 637
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 637
#
# Epoch 638
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 638
#
# Epoch 639
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 639
#
# Epoch 640
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 640
#
# Epoch 641
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 641
#
# Epoch 642
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 642
#
# Epoch 643
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 643
#
# Epoch 644
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 644
#
# Epoch 645
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 645
#
# Epoch 646
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 646
#
# Epoch 647
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 647
#
# Epoch 648
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 648
#
# Epoch 649
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 649
#
# Epoch 650
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 650
#
# Epoch 651
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 651
#
# Epoch 652
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 652
#
# Epoch 653
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 653
#
# Epoch 654
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 654
#
# Epoch 655
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 655
#
# Epoch 656
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 656
#
# Epoch 657
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 657
#
# Epoch 658
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 658
#
# Epoch 659
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 659
#
# Epoch 660
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 660
#
# Epoch 661
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 661
#
# Epoch 662
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 662
#
# Epoch 663
# Msg: Propagated set 2
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 663
#
# Epoch 664
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 664
#
# Epoch 665
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 665
#
# Epoch 666
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 666
#
# Epoch 667
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 667
#
# Epoch 668
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 668
#
# Epoch 669
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 669
#
# Epoch 670
# ...
#
# Epoch 873
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 873
#
# Epoch 874
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 874
#
# Epoch 875
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 875
#
# Epoch 876
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 876
#
# Epoch 877
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 877
#
# Epoch 878
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 878
#
# Epoch 879
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 879
#
# Epoch 880
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 880
#
# Epoch 881
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 881
#
# Epoch 882
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 882
#
# Epoch 883
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 883
#
# Epoch 884
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 884
#
# Epoch 885
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 885
#
# Epoch 886
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 886
#
# Epoch 887
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 887
#
# Epoch 888
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 888
#
# Epoch 889
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 889
#
# Epoch 890
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 890
#
# Epoch 891
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 891
#
# Epoch 892
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 892
#
# Epoch 893
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 893
#
# Epoch 894
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 894
#
# Epoch 895
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 895
#
# Epoch 896
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 896
#
# Epoch 897
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 4
# Learned in epoch 897
#
# Epoch 898
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 898
#
# Epoch 899
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 899
#
# Epoch 900
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 900
#
# Epoch 901
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 901
#
# Epoch 902
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 902
#
# Epoch 903
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 903
#
# Epoch 904
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 904
#
# Epoch 905
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 905
#
# Epoch 906
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 906
#
# Epoch 907
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 907
#
# Epoch 908
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 4
# Learned in epoch 908
#
# Epoch 909
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 909
#
# Epoch 910
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 910
#
# Epoch 911
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 911
#
# Epoch 912
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 912
#
# Epoch 913
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 913
#
# Epoch 914
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 914
#
# Epoch 915
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 915
#
# Epoch 916
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 916
#
# Epoch 917
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 917
#
# Epoch 918
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 918
#
# Epoch 919
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 919
#
# Epoch 920
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 920
#
# Epoch 921
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 921
#
# Epoch 922
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 922
#
# Epoch 923
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 923
#
# Epoch 924
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 924
#
# Epoch 925
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 925
#
# Epoch 926
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 926
#
# Epoch 927
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 927
#
# Epoch 928
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 928
#
# Epoch 929
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 4
# Learned in epoch 929
#
# Epoch 930
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 930
#
# Epoch 931
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 931
#
# Epoch 932
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 932
#
# Epoch 933
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 933
#
# Epoch 934
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 934
#
# Epoch 935
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 935
#
# Epoch 936
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 936
#
# Epoch 937
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 937
#
# Epoch 938
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 938
#
# Epoch 939
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 939
#
# Epoch 940
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 940
#
# Epoch 941
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 941
#
# Epoch 942
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 942
#
# Epoch 943
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 943
#
# Epoch 944
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 944
#
# Epoch 945
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 945
#
# Epoch 946
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 946
#
# Epoch 947
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 947
#
# Epoch 948
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 948
#
# Epoch 949
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 949
#
# Epoch 950
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 950
#
# Epoch 951
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 951
#
# Epoch 952
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 952
#
# Epoch 953
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 953
#
# Epoch 954
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 954
#
# Epoch 955
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 955
#
# Epoch 956
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 956
#
# Epoch 957
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 957
#
# Epoch 958
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 958
#
# Epoch 959
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 959
#
# Epoch 960
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 960
#
# Epoch 961
# Msg: Propagated set 2
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 961
#
# Epoch 962
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 962
#
# Epoch 963
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 963
#
# Epoch 964
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 964
#
# Epoch 965
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 965
#
# Epoch 966
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 966
#
# Epoch 967
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 967
#
# Epoch 968
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 968
#
# Epoch 969
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 969
#
# Epoch 970
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 970
#
# Epoch 971
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 971
#
# Epoch 972
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 972
#
# Epoch 973
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 973
#
# Epoch 974
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 974
#
# Epoch 975
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 975
#
# Epoch 976
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 976
#
# Epoch 977
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 977
#
# Epoch 978
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 978
#
# Epoch 979
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 979
#
# Epoch 980
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 980
#
# Epoch 981
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 1
# Msg: Propagated set 2
# Learned in epoch 981
#
# Epoch 982
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 982
#
# Epoch 983
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 983
#
# Epoch 984
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 984
#
# Epoch 985
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 985
#
# Epoch 986
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 986
#
# Epoch 987
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 987
#
# Epoch 988
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 3
# Msg: Propagated set 2
# Learned in epoch 988
#
# Epoch 989
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 3
# Msg: Propagated set 1
# Learned in epoch 989
#
# Epoch 990
# Msg: Propagated set 4
# Msg: Propagated set 2
# Msg: Propagated set 1
# Msg: Propagated set 3
# Learned in epoch 990
#
# Epoch 991
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 991
#
# Epoch 992
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 992
#
# Epoch 993
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 993
#
# Epoch 994
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 994
#
# Epoch 995
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 995
#
# Epoch 996
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 996
#
# Epoch 997
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 997
#
# Epoch 998
# Msg: Propagated set 4
# Msg: Propagated set 3
# Msg: Propagated set 2
# Msg: Propagated set 1
# Learned in epoch 998
#
# Epoch 999
# Msg: Propagated set 4
# Msg: Propagated set 1
# Msg: Propagated set 2
# Msg: Propagated set 3
# Learned in epoch 999
#
#
# ---------------------------
# METRICS
# ---------------------------
# Model error: 0.073234
# Execution took 735.631023ms
